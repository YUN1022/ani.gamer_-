# %%
import seaborn as sns

import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Plot the distribution of clarity ratings, conditional on carat
sns.displot(
    data=diamonds,
    x="carat", hue="cut",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
import pandas as pd 

df = pd.read_csv(r'D:\course\Social_Security\danmu\112522\112522_1.csv', encoding='utf-8-sig')
df
# Out:
#        time       text        userid  danmu_sn
# 0         0         ㄢㄢ      max80434  17075618
# 1         0          簽    kuanyy1130  17080292
# 2         0         二刷    chien77777  17108560
# 3         0  簽簽簽!!! 神作    zaq6643321  17112604
# 4         0         簽啦     R98181898  17197856
# ...     ...        ...           ...       ...
# 2996  14210   乾 ED有夠鳥肌    yuka915620  17588305
# 2997  14223      ED真的神      AlpheTIU  17463211
# 2998  14251        吸特勒  Kerry0915729  17094477
# 2999  14265       我婆><   mrsupergary  17081440
# 3000  14350          簽  Victor920104  17115081
#
# [3001 rows x 4 columns]

# %%
time_count = df['time'].value_counts()
time_count
# Out:
# 0        23
# 75        7
# 11496     6
# 905       6
# 115       5
#          ..
# 2602      1
# 10122     1
# 6700      1
# 4653      1
# 10248     1
# Name: time, Length: 2452, dtype: int64

# %%
df2 = pd.DataFrame({
    'time_count':time_count,
    
})
